# %%
#Importing TextBlob
from textblob import TextBlob

# %%
#we are considering a sample text to perform various operations using textblob toolkit
text =TextBlob("""ఆగష్టు - సెప్టంబర్ మాసాలు వస్తే చాలు.. ప్రకృతి ప్రేమికులందరూ ఎంచక్కా... అరుకులో వాలిపోతారు. విశాఖ ఏజెన్సీ ప్రాంతంలో ఉన్న ఈ సుందర అందాలను తిలికించేందకు మన రాష్ట్రం నుంచే కాక ఇతర రాష్ట్రాలు, విధేశాల నుంచి కూడా పర్యాటకులు వచ్చి విడిది చేస్తారు. ఏజన్సీ ప్రాంతంలో చలి తీవ్రత అధికంగా ఉన్న ఏ మాత్రం లెక్క చేయని పర్యాటకులు ప్రకృతి పరిమళాన్ని ఆస్వాదించటంతో పాటు ప్రకృతి అందాల మధ్య తమ మధుర జాపకాలను కెమోరా, వీడియో క్యామ్ లలో బంధిస్తారు. చలి కాలం ముగిసేంత వరకు ఇక్కడ పర్యాటకులు విడిది చేస్తుంటారు. సినిమా షూటింగులు సైతం ఈ రమణీయా సోయగాల మధ్యే తెరకెక్కుతాయి. ఇక కార్తీక మాసం వచ్చిందటే ఈ ప్రాంతం అధిక జనసమర్థతతో పులకించుపోతుంది. వన భోజనాలు పేరుతో కుటుంబ సమేతంగా ఈ ప్రాంతలో విడిదితీరి తెగ భలే ఎంజాయ్ చేస్తారు. ఏజన్సీలో చలి ఎక్కువగా వున్నప్పటికీ పర్యాటకులు లెక్క చేయడం లేదు. దీంతో రద్దీ బాగా పెరిగింది. చలిలో ఏజన్సీలో వుంటే ఎలా ఉంటుందో చూడాలన్న ఆసక్తితో పర్యాటకులు పెద్ద సంఖ్యలో తరలివస్తున్నారు. పర్యటకుల కోసం ఏపీ టూరిజం అన్ని వసతులు కల్పించింది. దీంతో ఇబ్బంది పడకుండా పర్యటకులు అరకులోని అన్ని ప్రాంతాలను సందర్శిస్తున్నారు. హోటల్లో సాయంత్రం పూట గిరిజన సంప్రదాయ నృత్యమైన థింసా ఏర్పాటు చేయటంతో పర్యాటకుల ఆనందానికి అవధులు లేవు.""")

# %%
#tokens identified from the text data
text.words
# Out:
# WordList(['ఆగష్టు', 'సెప్టంబర్', 'మాసాలు', 'వస్తే', 'చాలు', 'ప్రకృతి', 'ప్రేమికులందరూ', 'ఎంచక్కా', 'అరుకులో', 'వాలిపోతారు', 'విశాఖ', 'ఏజెన్సీ', 'ప్రాంతంలో', 'ఉన్న', 'ఈ', 'సుందర', 'అందాలను', 'తిలికించేందకు', 'మన', 'రాష్ట్రం', 'నుంచే', 'కాక', 'ఇతర', 'రాష్ట్రాలు', 'విధేశాల', 'నుంచి', 'కూడా', 'పర్యాటకులు', 'వచ్చి', 'విడిది', 'చేస్తారు', 'ఏజన్సీ', 'ప్రాంతంలో', 'చలి', 'తీవ్రత', 'అధికంగా', 'ఉన్న', 'ఏ', 'మాత్రం', 'లెక్క', 'చేయని', 'పర్యాటకులు', 'ప్రకృతి', 'పరిమళాన్ని', 'ఆస్వాదించటంతో', 'పాటు', 'ప్రకృతి', 'అందాల', 'మధ్య', 'తమ', 'మధుర', 'జాపకాలను', 'కెమోరా', 'వీడియో', 'క్యామ్', 'లలో', 'బంధిస్తారు', 'చలి', 'కాలం', 'ముగిసేంత', 'వరకు', 'ఇక్కడ', 'పర్యాటకులు', 'విడిది', 'చేస్తుంటారు', 'సినిమా', 'షూటింగులు', 'సైతం', 'ఈ', 'రమణీయా', 'సోయగాల', 'మధ్యే', 'తెరకెక్కుతాయి', 'ఇక', 'కార్తీక', 'మాసం', 'వచ్చిందటే', 'ఈ', 'ప్రాంతం', 'అధిక', 'జనసమర్థతతో', 'పులకించుపోతుంది', 'వన', 'భోజనాలు', 'పేరుతో', 'కుటుంబ', 'సమేతంగా', 'ఈ', 'ప్రాంతలో', 'విడిదితీరి', 'తెగ', 'భలే', 'ఎంజాయ్', 'చేస్తారు', 'ఏజన్సీలో', 'చలి', 'ఎక్కువగ
# ...

# %%
#post tagging
text.tags
# Out:
# [('ఆగష్టు', 'SYM'),
#  ('సెప్టంబర్', 'NN'),
#  ('మాసాలు', 'JJ'),
#  ('వస్తే', 'NNP'),
#  ('చాలు..', 'NNP'),
#  ('ప్రకృతి', 'NNP'),
#  ('ప్రేమికులందరూ', 'NNP'),
#  ('ఎంచక్కా', 'NNP'),
#  ('అరుకులో', 'JJ'),
#  ('వాలిపోతారు', 'NN'),
#  ('విశాఖ', 'JJ'),
#  ('ఏజెన్సీ', 'NNP'),
#  ('ప్రాంతంలో', 'NNP'),
#  ('ఉన్న', 'NNP'),
#  ('ఈ', 'NNP'),
#  ('సుందర', 'NNP'),
#  ('అందాలను', 'NNP'),
#  ('తిలికించేందకు', 'NNP'),
#  ('మన', 'NNP'),
#  ('రాష్ట్రం', 'NNP'),
#  ('నుంచే', 'NNP'),
#  ('కాక', 'NNP'),
#  ('ఇతర', 'NNP'),
#  ('రాష్ట్రాలు', 'NNP'),
#  ('విధేశాల', 'NNP'),
#  ('నుంచి', 'NNP'),
#  ('కూడా', 'NNP'),
#  ('పర్యాటకులు', 'NNP'),
#  ('వచ్చి', 'NNP'),
#  ('విడిది', 'NNP'),
#  ('చేస్తారు', 'NNP'),
#  ('ఏజన్సీ', 'JJ'),
#  ('ప్రాంతంలో', 'NNP'),
#  ('చలి', 'NNP'),
#  ('తీవ్రత', 'NNP'),
#  ('అధికంగా', 'NNP'),
#  ('ఉన్న', 'NNP'),
#  ('ఏ', 'NNP'),
#  ('మాత్రం', 'NNP'),
#  ('లెక్క', 'NNP'),
#  ('చేయని', 'NNP'),
#  ('పర్యాటకులు', 'NNP'),
#  ('ప్రకృతి', 'NNP'),
#  ('పరిమళాన్ని', 'NNP'),
# ...

# %%
#sentences can also be easily identified from the text document
text.sentences
# Out:
# [Sentence("ఆగష్టు - సెప్టంబర్ మాసాలు వస్తే చాలు.. ప్రకృతి ప్రేమికులందరూ ఎంచక్కా... అరుకులో వాలిపోతారు."),
#  Sentence("విశాఖ ఏజెన్సీ ప్రాంతంలో ఉన్న ఈ సుందర అందాలను తిలికించేందకు మన రాష్ట్రం నుంచే కాక ఇతర రాష్ట్రాలు, విధేశాల నుంచి కూడా పర్యాటకులు వచ్చి విడిది చేస్తారు."),
#  Sentence("ఏజన్సీ ప్రాంతంలో చలి తీవ్రత అధికంగా ఉన్న ఏ మాత్రం లెక్క చేయని పర్యాటకులు ప్రకృతి పరిమళాన్ని ఆస్వాదించటంతో పాటు ప్రకృతి అందాల మధ్య తమ మధుర జాపకాలను కెమోరా, వీడియో క్యామ్ లలో బంధిస్తారు."),
#  Sentence("చలి కాలం ముగిసేంత వరకు ఇక్కడ పర్యాటకులు విడిది చేస్తుంటారు."),
#  Sentence("సినిమా షూటింగులు సైతం ఈ రమణీయా సోయగాల మధ్యే తెరకెక్కుతాయి."),
#  Sentence("ఇక కార్తీక మాసం వచ్చిందటే ఈ ప్రాంతం అధిక జనసమర్థతతో పులకించుపోతుంది."),
#  Sentence("వన భోజనాలు పేరుతో కుటుంబ సమేతంగా ఈ ప్రాంతలో విడిదితీరి తెగ భలే ఎంజాయ్ చేస్తారు."),
#  Sentence("ఏజన్సీలో చలి ఎక్కువగా వున్నప్పటికీ పర్యాటకులు లెక్క చేయడం లేదు."),
#  Sentence("దీంతో రద్దీ బాగా పెరిగింది."),
# ...

# %%
#finding set of words based on ngram value
blob = TextBlob("పర్యటకుల కోసం ఏపీ టూరిజం అన్ని వసతులు కల్పించింది.")
blob.ngrams(n=3)
# Out:
# [WordList(['పర్యటకుల', 'కోసం', 'ఏపీ']),
#  WordList(['కోసం', 'ఏపీ', 'టూరిజం']),
#  WordList(['ఏపీ', 'టూరిజం', 'అన్ని']),
#  WordList(['టూరిజం', 'అన్ని', 'వసతులు']),
#  WordList(['అన్ని', 'వసతులు', 'కల్పించింది'])]
