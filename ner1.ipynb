# %%
import nltk

# %%
sentence = [("the", "DT"), ("little", "JJ"), ("yellow", "JJ"),("dog", "NN"), ("barked", "VBD"), ("at", "IN"),  ("the", "DT"), ("cat", "NN")]
grammar = "NP: {<DT>?<JJ>*<NN>}"

# %%
cp = nltk.RegexpParser(grammar)

# %%
result = cp.parse(sentence)

# %%
print(result)
# Out:
# (S
#   (NP the/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT cat/NN))

# %%
result.draw()

# %%
text = ("As a part of the course, students are required to develop a project, with a fully functional Database System consisting of the concepts learnt throughout the semester. ")

# %%
tokens = nltk.word_tokenize(text)

# %%
tags = nltk.pos_tag(tokens)

# %%
print(tokens)
# Out:
# ['As', 'a', 'part', 'of', 'the', 'course', ',', 'students', 'are', 'required', 'to', 'develop', 'a', 'project', ',', 'with', 'a', 'fully', 'functional', 'Database', 'System', 'consisting', 'of', 'the', 'concepts', 'learnt', 'throughout', 'the', 'semester', '.']

# %%
lor = cp.parse(tags)

# %%
print(lor)
# Out:
# (S
#   As/IN
#   (NP a/DT part/NN)
#   of/IN
#   (NP the/DT course/NN)
#   ,/,
#   students/NNS
#   are/VBP
#   required/VBN
#   to/TO
#   develop/VB
#   (NP a/DT project/NN)
#   ,/,
#   with/IN
#   a/DT
#   fully/RB
#   functional/JJ
#   Database/NNP
#   System/NNP
#   consisting/VBG
#   of/IN
#   the/DT
#   concepts/NNS
#   learnt/VBP
#   throughout/IN
#   (NP the/DT semester/NN)
#   ./.)

# %%
lor.draw()

# %%
chunks = nltk.ne_chunk(tags)

# %%
print(chunks)
# Out:
# (S
#   As/IN
#   a/DT
#   part/NN
#   of/IN
#   the/DT
#   course/NN
#   ,/,
#   students/NNS
#   are/VBP
#   required/VBN
#   to/TO
#   develop/VB
#   a/DT
#   project/NN
#   ,/,
#   with/IN
#   a/DT
#   fully/RB
#   functional/JJ
#   (ORGANIZATION Database/NNP)
#   System/NNP
#   consisting/VBG
#   of/IN
#   the/DT
#   concepts/NNS
#   learnt/VBP
#   throughout/IN
#   the/DT
#   semester/NN
#   ./.)

# %%
lor1 = """I was pleased to know that he applied the concepts in his internship extensively to build a professional tool for Intellect Design Arena. He designed this tool to make the process of configuring a Logical Data Model easier and much faster. It consisted of a User Interface (UI) that can replicate back-end tasks such as inserting data in a database at the click of a button. His task was cut out for him as the tool was being built for J.P. Morgan Chase as a client and hence there was no room for error. I am proud to say that the tool, which he built over a course of two months, was pushed to production at the end of his internship."""

# %%
reg1 = "RB:{<DT>*<JJ>*<NN.*>}"

# %%
cp1 = nltk.RegexpParser(reg1)

# %%
tags1 = nltk.pos_tag(lor1)

# %%
result1 = cp1.parse(tags1)

# %%
print(result1)
# Out:
# (S
#   I/PRP
#    /VBP
#   w/WRB
#   (RB a/DT s/NN)
#   (RB  /NNP)
#   (RB p/NN)
#   (RB l/NN)
#   e/VBZ
#   (RB a/DT s/JJ e/NN)
#   (RB d/NN)
#   (RB  /NNP)
#   (RB t/NN)
#   (RB o/NN)
#   (RB  /NNP)
#   (RB k/NN)
#   (RB n/NNP)
#   o/VBZ
#   (RB w/JJ  /NNP)
#   (RB t/NN)
#   h/VBD
#   (RB a/DT t/NN)
#   (RB  /NN)
#   (RB h/NN)
#   (RB e/NN)
#    /VBZ
#   (RB a/DT p/NN)
#   (RB p/NN)
#   (RB l/NN)
#   (RB i/NN)
#   e/VBP
#   (RB d/NN)
#   (RB  /NNP)
#   (RB t/NN)
#   (RB h/NN)
#   (RB e/NN)
#   (RB  /NNP)
#   c/VBZ
#   (RB o/JJ n/JJ c/NN)
#   (RB e/NN)
#   (RB p/NN)
#   (RB t/NN)
#   (RB s/NN)
#   (RB  /NN)
#   (RB i/NN)
#   n/VBP
#    /IN
#   (RB h/NN)
#   (RB i/NN)
#   s/VBP
#   (RB  /NN)
#   (RB i/NN)
#   n/VBP
#   (RB t/NN)
#   (RB e/NN)
#   (RB r/NN)
#   (RB n/JJ s/NN)
#   (RB h/NN)
#   i/JJ
#   p/VBP
#   (RB  /JJ e/NN)
#   (RB x/NNP)
#   (RB t/NN)
#   (RB e/NN)
#   n/IN
#   (RB s/NN)
#   (RB i/NN)
#   v/VBP
#   (RB e/NN)
#   (RB l/NN)
#   (RB y/NN)
#   (RB  /NNP)
# ...

# %%
result1.draw()

# %%
reg_chink1 = "RB:}<DT>*<JJ>*<NN.*>{"

# %%
reg_cp1 = nltk.RegexpParser(reg_chink1)

# %%
tags1 = nltk.pos_tag(loc1)

# %%
result_chink1 = reg_cp1.parse(tags1)

# %%
print(result_chink1)
